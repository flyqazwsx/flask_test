# %%
import pandas as pd

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_432?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=ImportDate%20desc&format=CSV'

# %%
df=pd.read_csv(url)
df
# Out:
#    sitename county  aqi pollutant status  so2    co    o3  o3_8hr  pm10  ...  \
# 0        基隆    基隆市   25       NaN     良好  0.6  0.20  35.5    27.3     9  ...
# 1        汐止    新北市   21       NaN     良好  0.2  0.21  30.6    23.4     1  ...
# 2        萬里    新北市   40       NaN     良好  0.5  0.17  40.1    32.4    55  ...
# 3        新店    新北市   21       NaN     良好  0.5  0.27  31.4    23.7     0  ...
# 4        土城    新北市   20       NaN     良好  0.3  0.26  31.1    22.0     9  ...
# ..      ...    ...  ...       ...    ...  ...   ...   ...     ...   ...  ...
# 81   屏東(琉球)    屏東縣   98     細懸浮微粒     普通  1.3  0.28  52.6    50.6    50  ...
# 82   宜蘭(壯圍)    宜蘭縣   35       NaN     良好  0.0  0.17  39.2    30.1    34  ...
# 83   新北(樹林)    新北市   17       NaN     良好  0.2  0.27  24.4    14.1     1  ...
# 84   臺南(學甲)    臺南市   53     細懸浮微粒     普通  0.9  0.39  33.8    23.4    39  ...
# 85   屏東(枋山)    屏東縣   97     細懸浮微粒     普通  1.1  0.28  66.6    59.6    58  ...
#
# ...

# %%
df.drop(["pollutant"],axis=1)
# Out:
#    sitename county  aqi status  so2    co    o3  o3_8hr  pm10  pm2.5  ...  \
# 0        基隆    基隆市   25     良好  0.6  0.20  35.5    27.3     9      4  ...
# 1        汐止    新北市   21     良好  0.2  0.21  30.6    23.4     1      3  ...
# 2        萬里    新北市   40     良好  0.5  0.17  40.1    32.4    55      4  ...
# 3        新店    新北市   21     良好  0.5  0.27  31.4    23.7     0      0  ...
# 4        土城    新北市   20     良好  0.3  0.26  31.1    22.0     9      2  ...
# ..      ...    ...  ...    ...  ...   ...   ...     ...   ...    ...  ...
# 81   屏東(琉球)    屏東縣   98     普通  1.3  0.28  52.6    50.6    50     27  ...
# 82   宜蘭(壯圍)    宜蘭縣   35     良好  0.0  0.17  39.2    30.1    34      6  ...
# 83   新北(樹林)    新北市   17     良好  0.2  0.27  24.4    14.1     1      3  ...
# 84   臺南(學甲)    臺南市   53     普通  0.9  0.39  33.8    23.4    39     16  ...
# 85   屏東(枋山)    屏東縣   97     普通  1.1  0.28  66.6    59.6    58     38  ...
#
#     wind_speed  wind_direc          publishtime co_8hr pm2.5_avg pm10_avg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sitename     86 non-null     object
#  1   county       86 non-null     object
#  2   aqi          86 non-null     int64
#  3   pollutant    43 non-null     object
#  4   status       86 non-null     object
#  5   so2          85 non-null     float64
#  6   co           86 non-null     float64
#  7   o3           86 non-null     float64
#  8   o3_8hr       86 non-null     float64
#  9   pm10         86 non-null     int64
#  10  pm2.5        86 non-null     int64
#  11  no2          85 non-null     float64
#  12  nox          85 non-null     float64
#  13  no           85 non-null     float64
#  14  wind_speed   84 non-null     object
#  15  wind_direc   84 non-null     object
#  16  publishtime  86 non-null     object
#  17  co_8hr       86 non-null     float64
# ...

# %%
df=df.dropna()
df
# Out:
#    sitename county  aqi pollutant    status  so2    co    o3  o3_8hr  pm10  \
# 2        萬里    新北市   54     細懸浮微粒        普通  0.5  0.39  47.8    44.7    68
# 15       大同    臺北市   56     細懸浮微粒        普通  1.0  0.50  39.1    33.0    39
# 16       桃園    桃園市   56     細懸浮微粒        普通  1.5  0.46  45.6    37.2    37
# 21       湖口    新竹縣   51     細懸浮微粒        普通  1.4  0.37  46.8    38.8    37
# 27       豐原    臺中市   54     細懸浮微粒        普通  0.8  0.37  10.3    28.5    22
# 31       西屯    臺中市   52     細懸浮微粒        普通  1.1  0.26  18.2    37.5    24
# 32       彰化    彰化縣   52     細懸浮微粒        普通  1.0  0.37  16.4    35.4    30
# 34       二林    彰化縣   52     細懸浮微粒        普通  2.4  0.22  23.3    37.5    46
# 35       南投    南投縣   60     細懸浮微粒        普通  1.2  0.44   5.8    46.5    44
# 36       斗六    雲林縣   72     細懸浮微粒        普通  1.6  0.33  19.9    46.1    51
# 37       崙背    雲林縣   67     細懸浮微粒        普通  1.5  0.43  17.9    36.3    41
# ...

# %%
df['pm2.5']
# Out:
# 2     18
# 15    19
# 16    19
# 21    21
# 27    17
# 31    15
# 32    16
# 34    12
# 35    15
# 36    24
# 37    17
# 38    16
# 39    57
# 41    27
# 43    20
# 44    22
# 45    19
# 46    29
# 47    33
# 48    35
# 49    36
# 50    52
# 51    33
# 52    30
# 53    31
# 54    32
# 55    30
# 56    45
# 57    40
# 58    29
# 69    32
# 70    18
# 71    15
# 75    14
# 76    18
# 78    19
# 79    29
# 80    11
# 81    21
# 84    19
# 85    35
# Name: pm2.5, dtype: int64

# %%
df1=df['sitename	aqi	no2	pm2.5'.split()]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 2 to 85
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sitename  41 non-null     object
#  1   aqi       41 non-null     int64
#  2   no2       41 non-null     float64
#  3   pm2.5     41 non-null     int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 1.6+ KB

# %%
df1.columns.tolist()
# Out:
# ['sitename', 'aqi', 'no2', 'publishtime']

# %%
df1.values.tolist()
# Out:
# [['臺南', 55, 9.3, '2022/11/06 21:00:00'],
#  ['美濃', 67, 8.3, '2022/11/06 21:00:00'],
#  ['橋頭', 66, 10.5, '2022/11/06 21:00:00'],
#  ['仁武', 68, 12.1, '2022/11/06 21:00:00'],
#  ['鳳山', 70, 19.7, '2022/11/06 21:00:00'],
#  ['大寮', 72, 8.6, '2022/11/06 21:00:00'],
#  ['林園', 71, 4.4, '2022/11/06 21:00:00'],
#  ['楠梓', 58, 11.8, '2022/11/06 21:00:00'],
#  ['左營', 64, 10.8, '2022/11/06 21:00:00'],
#  ['前金', 71, 16.1, '2022/11/06 21:00:00'],
#  ['前鎮', 71, 17.0, '2022/11/06 21:00:00'],
#  ['小港', 74, 21.5, '2022/11/06 21:00:00'],
#  ['屏東', 83, 13.5, '2022/11/06 21:00:00'],
#  ['潮州', 94, 7.3, '2022/11/06 21:00:00'],
#  ['復興', 59, 16.9, '2022/11/06 21:00:00'],
#  ['高雄(湖內)', 58, 7.8, '2022/11/06 21:00:00'],
#  ['屏東(琉球)', 80, 3.6, '2022/11/06 21:00:00']]

# %%
df1['sitename']
# Out:
# 45        臺南
# 46        美濃
# 47        橋頭
# 48        仁武
# 49        鳳山
# 50        大寮
# 51        林園
# 52        楠梓
# 53        左營
# 54        前金
# 55        前鎮
# 56        小港
# 57        屏東
# 58        潮州
# 69        復興
# 79    高雄(湖內)
# 81    屏東(琉球)
# Name: sitename, dtype: object

# %%
sitename=list(set(df1['sitename']))
sitename
# Out:
# ['臺南',
#  '橋頭',
#  '前鎮',
#  '仁武',
#  '林園',
#  '屏東',
#  '復興',
#  '左營',
#  '小港',
#  '美濃',
#  '鳳山',
#  '楠梓',
#  '前金',
#  '屏東(琉球)',
#  '大寮',
#  '潮州',
#  '高雄(湖內)']

# %%
no2=list(df1['no2'])
no2
# Out:
# [9.3,
#  8.3,
#  10.5,
#  12.1,
#  19.7,
#  8.6,
#  4.4,
#  11.8,
#  10.8,
#  16.1,
#  17.0,
#  21.5,
#  13.5,
#  7.3,
#  16.9,
#  7.8,
#  3.6]

# %%
df1.groupby('sitename').get_group(sitename[0])
# Out:
#    sitename  aqi  no2          publishtime
# 45       臺南   55  9.3  2022/11/06 21:00:00

# %%
df1['no2']
# Out:
# 45     9.3
# 46     8.3
# 47    10.5
# 48    12.1
# 49    19.7
# 50     8.6
# 51     4.4
# 52    11.8
# 53    10.8
# 54    16.1
# 55    17.0
# 56    21.5
# 57    13.5
# 58     7.3
# 69    16.9
# 79     7.8
# 81     3.6
# Name: no2, dtype: float64

# %%
datas=[]

# %%
for sitename in df1['sitename']:
    no2=df1.groupby('sitename').get_group(sitename)['no2']
    datas.append([sitename,no2])
datas
# Out:
# [['臺南',
#   45    9.3
#   Name: no2, dtype: float64],
#  ['美濃',
#   46    8.3
#   Name: no2, dtype: float64],
#  ['橋頭',
#   47    10.5
#   Name: no2, dtype: float64],
#  ['仁武',
#   48    12.1
#   Name: no2, dtype: float64],
#  ['鳳山',
#   49    19.7
#   Name: no2, dtype: float64],
#  ['大寮',
#   50    8.6
#   Name: no2, dtype: float64],
#  ['林園',
#   51    4.4
#   Name: no2, dtype: float64],
#  ['楠梓',
#   52    11.8
#   Name: no2, dtype: float64],
#  ['左營',
#   53    10.8
#   Name: no2, dtype: float64],
#  ['前金',
#   54    16.1
#   Name: no2, dtype: float64],
#  ['前鎮',
#   55    17.0
#   Name: no2, dtype: float64],
#  ['小港',
#   56    21.5
#   Name: no2, dtype: float64],
#  ['屏東',
#   57    13.5
#   Name: no2, dtype: float64],
#  ['潮州',
#   58    7.3
#   Name: no2, dtype: float64],
#  ['復興',
#   69    16.9
#   Name: no2, dtype: float64],
#  ['高雄(湖內)',
#   79    7.8
#   Name: no2, dtype: float64],
#  ['屏東(琉球)',
#   81    3.6
#   Name: no2, dtype: float64],
#  ['臺南',
#   45    9.3
# ...

# %%
datas[0][1]
# Out:
# 45    9.3
# Name: no2, dtype: float64

# %%
sitename=[sitename[0] for sitename in datas]

# %%
sitename
# Out:
# ['臺南',
#  '美濃',
#  '橋頭',
#  '仁武',
#  '鳳山',
#  '大寮',
#  '林園',
#  '楠梓',
#  '左營',
#  '前金',
#  '前鎮',
#  '小港',
#  '屏東',
#  '潮州',
#  '復興',
#  '高雄(湖內)',
#  '屏東(琉球)']

# %%
datas
# Out:
# [['臺南',
#   45    9.3
#   Name: no2, dtype: float64],
#  ['美濃',
#   46    8.3
#   Name: no2, dtype: float64],
#  ['橋頭',
#   47    10.5
#   Name: no2, dtype: float64],
#  ['仁武',
#   48    12.1
#   Name: no2, dtype: float64],
#  ['鳳山',
#   49    19.7
#   Name: no2, dtype: float64],
#  ['大寮',
#   50    8.6
#   Name: no2, dtype: float64],
#  ['林園',
#   51    4.4
#   Name: no2, dtype: float64],
#  ['楠梓',
#   52    11.8
#   Name: no2, dtype: float64],
#  ['左營',
#   53    10.8
#   Name: no2, dtype: float64],
#  ['前金',
#   54    16.1
#   Name: no2, dtype: float64],
#  ['前鎮',
#   55    17.0
#   Name: no2, dtype: float64],
#  ['小港',
#   56    21.5
#   Name: no2, dtype: float64],
#  ['屏東',
#   57    13.5
#   Name: no2, dtype: float64],
#  ['潮州',
#   58    7.3
#   Name: no2, dtype: float64],
#  ['復興',
#   69    16.9
#   Name: no2, dtype: float64],
#  ['高雄(湖內)',
#   79    7.8
#   Name: no2, dtype: float64],
#  ['屏東(琉球)',
#   81    3.6
#   Name: no2, dtype: float64]]

# %%
no2=[no2[1] for no2 in datas]

# %%
no2
# Out:
# [45    9.3
#  Name: no2, dtype: float64,
#  46    8.3
#  Name: no2, dtype: float64,
#  47    10.5
#  Name: no2, dtype: float64,
#  48    12.1
#  Name: no2, dtype: float64,
#  49    19.7
#  Name: no2, dtype: float64,
#  50    8.6
#  Name: no2, dtype: float64,
#  51    4.4
#  Name: no2, dtype: float64,
#  52    11.8
#  Name: no2, dtype: float64,
#  53    10.8
#  Name: no2, dtype: float64,
#  54    16.1
#  Name: no2, dtype: float64,
#  55    17.0
#  Name: no2, dtype: float64,
#  56    21.5
#  Name: no2, dtype: float64,
#  57    13.5
#  Name: no2, dtype: float64,
#  58    7.3
#  Name: no2, dtype: float64,
#  69    16.9
#  Name: no2, dtype: float64,
#  79    7.8
#  Name: no2, dtype: float64,
#  81    3.6
#  Name: no2, dtype: float64]
