# %%
import pandas as pd
import json,requests
from pandas import json_normalize

# %%
url = requests.get("https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON")
text = url.text
data = json.loads(text)
data
# Out:
# {'cwbopendata': {'@xmlns': 'urn:cwb:gov:tw:cwbcommon:0.1',
#   'identifier': '9aac8dc2-c92e-100d-54a1-b82010b6df69',
#   'sender': 'weather@cwb.gov.tw',
#   'sent': '2022-10-10T16:42:02+08:00',
#   'status': 'Actual',
#   'msgType': 'Issue',
#   'source': 'MFC',
#   'dataid': 'C0032-001',
#   'scope': 'Public',
#   'dataset': {'datasetInfo': {'datasetDescription': '三十六小時天氣預報',
#     'issueTime': '2022-10-10T17:00:00+08:00',
#     'update': '2022-10-10T16:42:02+08:00'},
#    'location': [{'locationName': '臺北市',
#      'weatherElement': [{'elementName': 'Wx',
#        'time': [{'startTime': '2022-10-10T18:00:00+08:00',
#          'endTime': '2022-10-11T06:00:00+08:00',
#          'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#         {'startTime': '2022-10-11T06:00:00+08:00',
#          'endTime': '2022-10-11T18:00:00+08:00',
#          'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#         {'startTime': '2022-10-11T18:00:00+08:00',
# ...

# %%
df = json_normalize(data['cwbopendata']['dataset']['location']) 
df['weatherElement'][0]
# Out:
# [{'elementName': 'Wx',
#   'time': [{'startTime': '2022-10-10T18:00:00+08:00',
#     'endTime': '2022-10-11T06:00:00+08:00',
#     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#    {'startTime': '2022-10-11T06:00:00+08:00',
#     'endTime': '2022-10-11T18:00:00+08:00',
#     'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#    {'startTime': '2022-10-11T18:00:00+08:00',
#     'endTime': '2022-10-12T06:00:00+08:00',
#     'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}}]},
#  {'elementName': 'MaxT',
#   'time': [{'startTime': '2022-10-10T18:00:00+08:00',
#     'endTime': '2022-10-11T06:00:00+08:00',
#     'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#    {'startTime': '2022-10-11T06:00:00+08:00',
#     'endTime': '2022-10-11T18:00:00+08:00',
#     'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#    {'startTime': '2022-10-11T18:00:00+08:00',
#     'endTime': '2022-10-12T06:00:00+08:00',
# ...

# %%
df1=df[df['locationName']=='臺北市']

# %%
dfs=json_normalize(df['weatherElement'][0])
dfs
# Out:
#   elementName                                               time
# 0          Wx  [{'startTime': '2022-10-10T18:00:00+08:00', 'e...
# 1        MaxT  [{'startTime': '2022-10-10T18:00:00+08:00', 'e...
# 2        MinT  [{'startTime': '2022-10-10T18:00:00+08:00', 'e...
# 3          CI  [{'startTime': '2022-10-10T18:00:00+08:00', 'e...
# 4         PoP  [{'startTime': '2022-10-10T18:00:00+08:00', 'e...

# %%
dfs=json_normalize(df['weatherElement'][0])
dfs['time'][0]
# Out:
# [{'startTime': '2022-10-10T18:00:00+08:00',
#   'endTime': '2022-10-11T06:00:00+08:00',
#   'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#  {'startTime': '2022-10-11T06:00:00+08:00',
#   'endTime': '2022-10-11T18:00:00+08:00',
#   'parameter': {'parameterName': '陰天', 'parameterValue': '7'}},
#  {'startTime': '2022-10-11T18:00:00+08:00',
#   'endTime': '2022-10-12T06:00:00+08:00',
#   'parameter': {'parameterName': '陰短暫雨', 'parameterValue': '11'}}]

# %%
dfs['time'][1]
# Out:
# [{'startTime': '2022-10-10T18:00:00+08:00',
#   'endTime': '2022-10-11T06:00:00+08:00',
#   'parameter': {'parameterName': '21', 'parameterUnit': 'C'}},
#  {'startTime': '2022-10-11T06:00:00+08:00',
#   'endTime': '2022-10-11T18:00:00+08:00',
#   'parameter': {'parameterName': '22', 'parameterUnit': 'C'}},
#  {'startTime': '2022-10-11T18:00:00+08:00',
#   'endTime': '2022-10-12T06:00:00+08:00',
#   'parameter': {'parameterName': '22', 'parameterUnit': 'C'}}]

# %%
county_1=[]
for idx,row in dfs.iterrows():
    a=json_normalize(row['time'])
    county_1.append(a.values.tolist())
county_1
# Out:
# [[['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '陰天', '7'],
#   ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '陰天', '7'],
#   ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '陰短暫雨', '11']],
#  [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '21', 'C'],
#   ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '22', 'C'],
#   ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '22', 'C']],
#  [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '20', 'C'],
#   ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '20', 'C'],
#   ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '21', 'C']],
#  [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '稍有寒意至舒適'],
#   ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '稍有寒意至舒適'],
#   ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '舒適']],
#  [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '10', '百分比'],
# ...

# %%
a.values.tolist()
# Out:
# [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '10', '百分比'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '20', '百分比'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '50', '百分比']]

# %%
county_11=[]
for value in county_1:
    for td in value:
        county_11.append(td)
county_11
# Out:
# [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '陰天', '7'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '陰天', '7'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '陰短暫雨', '11'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '21', 'C'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '22', 'C'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '22', 'C'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '20', 'C'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '20', 'C'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '21', 'C'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '稍有寒意至舒適'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '稍有寒意至舒適'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '舒適'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '10', '百分比'],
# ...

# %%
for value in county_11:
    for td in value:
        print(td)
# Out:
# 2022-10-10T18:00:00+08:00
# 2022-10-11T06:00:00+08:00
# 陰天
# 7
# 2022-10-11T06:00:00+08:00
# 2022-10-11T18:00:00+08:00
# 陰天
# 7
# 2022-10-11T18:00:00+08:00
# 2022-10-12T06:00:00+08:00
# 陰短暫雨
# 11
# 2022-10-10T18:00:00+08:00
# 2022-10-11T06:00:00+08:00
# 21
# C
# 2022-10-11T06:00:00+08:00
# 2022-10-11T18:00:00+08:00
# 22
# C
# 2022-10-11T18:00:00+08:00
# 2022-10-12T06:00:00+08:00
# 22
# C
# 2022-10-10T18:00:00+08:00
# 2022-10-11T06:00:00+08:00
# 20
# C
# 2022-10-11T06:00:00+08:00
# 2022-10-11T18:00:00+08:00
# 20
# C
# 2022-10-11T18:00:00+08:00
# 2022-10-12T06:00:00+08:00
# 21
# C
# 2022-10-10T18:00:00+08:00
# 2022-10-11T06:00:00+08:00
# 稍有寒意至舒適
# 2022-10-11T06:00:00+08:00
# 2022-10-11T18:00:00+08:00
# 稍有寒意至舒適
# 2022-10-11T18:00:00+08:00
# 2022-10-12T06:00:00+08:00
# 舒適
# 2022-10-10T18:00:00+08:00
# 2022-10-11T06:00:00+08:00
# 10
# 百分比
# 2022-10-11T06:00:00+08:00
# 2022-10-11T18:00:00+08:00
# 20
# 百分比
# 2022-10-11T18:00:00+08:00
# 2022-10-12T06:00:00+08:00
# 50
# 百分比

# %%
df
# Out:
#    locationName                                     weatherElement
# 0           臺北市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 1           新北市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 2           桃園市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 3           臺中市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 4           臺南市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 5           高雄市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 6           基隆市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 7           新竹縣  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 8           新竹市  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 9           苗栗縣  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 10          彰化縣  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 11          南投縣  [{'elementName': 'Wx', 'time': [{'startTime': ...
# 12          雲林縣  [{'elementName': 'Wx', 'time': [{'startTime': ...
# ...

# %%
df['locationName']
# Out:
# 0     臺北市
# 1     新北市
# 2     桃園市
# 3     臺中市
# 4     臺南市
# 5     高雄市
# 6     基隆市
# 7     新竹縣
# 8     新竹市
# 9     苗栗縣
# 10    彰化縣
# 11    南投縣
# 12    雲林縣
# 13    嘉義縣
# 14    嘉義市
# 15    屏東縣
# 16    宜蘭縣
# 17    花蓮縣
# 18    臺東縣
# 19    澎湖縣
# 20    金門縣
# 21    連江縣
# Name: locationName, dtype: object

# %%
qq='臺北市'

# %%
if qq in df['locationName'][0]:
    dfs = json_normalize(df['weatherElement'][0])
    county_11 = []
    county_1 = []
    for idx, row in dfs.iterrows():
        a = json_normalize(row['time'])
        county_1.append(a.values.tolist())
    for value in county_1:
        for td in value:
            county_11.append(td)
county_11
# Out:
# [['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '陰天', '7'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '陰天', '7'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '陰短暫雨', '11'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '21', 'C'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '22', 'C'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '22', 'C'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '20', 'C'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '20', 'C'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '21', 'C'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '稍有寒意至舒適'],
#  ['2022-10-11T06:00:00+08:00', '2022-10-11T18:00:00+08:00', '稍有寒意至舒適'],
#  ['2022-10-11T18:00:00+08:00', '2022-10-12T06:00:00+08:00', '舒適'],
#  ['2022-10-10T18:00:00+08:00', '2022-10-11T06:00:00+08:00', '10', '百分比'],
# ...
